# %%
import glob

glob.glob('*/index.md')
# Out:
# ['plydata/index.md',
#  'embeddings_resource_usage_method/index.md',
#  '2023-04-25-tomotopy_is_the_fastest_topic_model/index.md',
#  '2023-12-18-how-to-generate-panel-data-from-daily-news-dataset/index.md',
#  '2024-08-06-using-the-ollama-local-large-model-to-predict-the-sentiment-category-of-online-comments/index.md',
#  'ai_and_graph_database_technology/index.md',
#  'techweekly14/index.md',
#  'spacy_industry_application/index.md',
#  '2021-12-08-i-qi-cha/index.md',
#  '2024-07-12-china-daily-dataset/index.md',
#  '2022-11-07-embeddings-theory-applicaiton-liuhuanyong/index.md',
#  'techweekly13/index.md',
#  '2024-06-14-using-large-language-model-to-extract-structure-data-from-raw-text/index.md',
#  '2024-06-22-usa_today_daily-news-dataset/index.md',
#  '2023-10-07-esg-measurement/index.md',
#  'pychorus/index.md',
#  '2024-01-21-hk-stock-market-anual-report/index.md',
#  'qdata_collect_baidu_index/index.md',
#  '2023-04-12-china-poi-datasets/index.md',
# ...

# %%
text = open('2024-08-03-literature-document-parsing-using-large-language-models-with-code/index.md').read()

# %%
ad_text = '{{< figure src="/images/bg/management_data_mining_with_python_course2.png" caption="点击了解课程详情"  align="center" width="100%" link="https://textdata.cn/blog/management_python_course/">}}'

for md_f in glob.glob('*/index.md'):
    text = open(md_f).read()
    if '精选内容' in text or '相关内容' in text:
        print(md_f)
            
        #new_text = text.split('## 广而告之')[0]+ ad_text
        
        #with open(md_f, mode='w', encoding='utf-8')  as nf:
        #    nf.write(new_text)
# Out:
# 2024-08-06-using-the-ollama-local-large-model-to-predict-the-sentiment-category-of-online-comments/index.md
# 2024-07-12-china-daily-dataset/index.md
# 2024-06-14-using-large-language-model-to-extract-structure-data-from-raw-text/index.md
# 2024-06-22-usa_today_daily-news-dataset/index.md
# 2024-01-21-hk-stock-market-anual-report/index.md
# 2024-06-16-scrapegraph-ai/index.md
# 2025-02-22-extracting-structured-data-from-images-with-ollama-and-large-language-models/index.md
# 2025-03-05-scrape-consumer-complaint-data-with-python/index.md
# 2024-06-05-wenzheng-hunan-dataset/index.md
# 2024-04-16-douban-movie-1000w-ratings-comments-dataset/index.md
# 2023-12-29-china-area-dataset/index.md
# 2023-11-03-organization-science-with-word-embeddings/index.md
# 2023-02-26-cctv1-xwlb-news-text-dataset/index.md
# 2023-11-10-training-word2vec-model-using-china-3751w-patent-application-dataset/index.md
# 2024-04-19-ai-improve-firm-productivity/index.md
# 2024-07-08-open-sanctions-dataset/index.md
# ...

# %%
print(text)''
# Out:
# ---
# title: 实验 | 使用本地大模型从论文PDF中提取结构化信息
# author: 大邓
# date: '2024-08-03'
# slug: 2024-08-03-literature-document-parsing-using-large-language-models-with-code
# categories: []
# tags:
#   - LLM
#   - 文本分析
# cover:
#   image: images/blog/document-parsing-using-llm.jpg
# description:   非结构文本、图片、视频等数据是待挖掘的数据矿藏， 在经管、社科等研究领域中谁拥有了从非结构提取结构化信息的能力，谁就拥有科研上的数据优势。正则表达式是一种强大的文档解析工具，但它们常常难以应对现实世界文档的复杂性和多变性。而随着chatGPT这类LLM的出现，为我们提供了更强大、更灵活的方法来处理多种类型的文档结构和内容类型。For many years, regular expressions have been my go-to tool for parsing documents, and I am sure it has been the same for many other technical folks and industries.Even though regular expressions are powerful and successful in some case, they often struggle with the complexity and variability of real-world documents.Large language models on the other end provide a more powerful, and flexible approach to handle many types of document structures and content types.
# keywords:
#   - Python
#   - 大模型
#   - ollama
#   - 文献整理
# ...

# %%
ad_text = '{{< figure src="/images/bg/management_data_mining_with_python_course2.png" caption="点击了解课程详情"  align="center" width="100%" link="https://textdata.cn/blog/management_python_course/">}}'

for md_f in glob.glob('*/index.md'):
    text = open(md_f).read()
    if ad_text not in text:
        print(md_f)
        #new_text = text + '<br>\n<br>\n' + ad_text
        
        #with open(md_f, mode='w', encoding='utf-8')  as nf:
        #    nf.write(new_text)
# Out:
# ai_and_graph_database_technology/index.md
# techweekly14/index.md
# techweekly13/index.md
# pychorus/index.md
# Geospatial_With_Greppo/index.md
# Basic-01-Python-is-a-language/index.md
# Basic-02-Win-Settings/index.md
# quant_lang/index.md
# techweekly12/index.md
# techweekly15/index.md
# we_need_you/index.md
# 2022-05-workshop/index.md
# Basic-15-common-errors/index.md
# Basic-03-Mac-Settings/index.md
# Basic-11-Built-Function/index.md
# hitomi_downloader/index.md
# Basic-12-pathlib/index.md
# Basic-07-Boolean-None/index.md
# nlp-history-timeline/index.md
# 2022-09-19-text-mining-in-ms-workshop/index.md
# techweekly06/index.md
# techweekly01/index.md
# techweekly08/index.md
# Basic-10-Understand-Function/index.md
# techweekly09/index.md
# techweekly07/index.md
# beautiful_harbin_scene/index.md
# techweekly19/index.md
# techweekly10/index.md
# techweekly17/index.md
# techweekly16/index.md
# techweekly11/index.md
# Basic-08-Logical-if-else-try-except/index.md
# math_add_sub/index.md
# ...
